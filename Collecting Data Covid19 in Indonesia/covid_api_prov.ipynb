# %%
import requests
import pandas as pd 
import numpy as np

# %% [markdown]
# # Banten

# %%
resp_banten = requests.get('https://data.covid19.go.id/public/api/prov_detail_BANTEN.json')
resp_banten
# Out:
# <Response [200]>

# %%
prov_banten_raw = resp_banten.json()
prov_banten_raw.keys()
# Out:
# dict_keys(['last_date', 'provinsi', 'kasus_total', 'kasus_tanpa_tgl', 'kasus_dengan_tgl', 'meninggal_persen', 'meninggal_tanpa_tgl', 'meninggal_dengan_tgl', 'sembuh_persen', 'sembuh_tanpa_tgl', 'sembuh_dengan_tgl', 'list_perkembangan', 'data'])

# %%
prov_banten = prov_banten_raw['list_perkembangan']
prov_banten = pd.DataFrame(prov_banten)

# %%
print(prov_banten.info())
prov_banten
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tanggal                       435 non-null    int64
#  1   KASUS                         435 non-null    int64
#  2   MENINGGAL                     435 non-null    int64
#  3   SEMBUH                        435 non-null    int64
#  4   DIRAWAT_OR_ISOLASI            435 non-null    int64
#  5   AKUMULASI_KASUS               435 non-null    int64
#  6   AKUMULASI_SEMBUH              435 non-null    int64
#  7   AKUMULASI_MENINGGAL           435 non-null    int64
#  8   AKUMULASI_DIRAWAT_OR_ISOLASI  435 non-null    int64
# dtypes: int64(9)
# memory usage: 30.7 KB
# None
#            tanggal  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    1583452800000      1          0       1                   0
# 1    1583539200000      0          0       0                   0
# 2    1583625600000      1          0       3                  -2
# 3    1583712000000      0          0       0                   0
# 4    1583798400000      0          0       8                  -8
# ..             ...    ...        ...     ...                 ...
# 430  1620604800000     92          4      71                  17
# 431  1620691200000     82          1      45                  36
# 432  1620777600000     56          0      24                  32
# 433  1620864000000     34          0       1                  33
# 434  1620950400000     39          0      15                  24
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  1                 1                    0
# 1                  1                 1                    0
# 2                  2                 4                    0
# 3                  2                 4                    0
# 4                  2                12                    0
# ..               ...               ...                  ...
# 430            48129             44961                 1223
# 431            48211             45006                 1224
# 432            48267             45030                 1224
# 433            48301             45031                 1224
# 434            48340             45046                 1224
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               0
# 1                               0
# 2                              -2
# 3                              -2
# 4                             -10
# ..                            ...
# 430                          1945
# 431                          1981
# 432                          2013
# 433                          2046
# 434                          2070
#
# [435 rows x 9 columns]

# %%
prov_banten['tanggal'] = pd.to_datetime(prov_banten['tanggal']*1e6 ,unit='ns')
prov_banten.insert(1, 'provinsi', 'Banten')
prov_banten
# Out:
#        tanggal provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-06   Banten      1          0       1                   0
# 1   2020-03-07   Banten      0          0       0                   0
# 2   2020-03-08   Banten      1          0       3                  -2
# 3   2020-03-09   Banten      0          0       0                   0
# 4   2020-03-10   Banten      0          0       8                  -8
# ..         ...      ...    ...        ...     ...                 ...
# 430 2021-05-10   Banten     92          4      71                  17
# 431 2021-05-11   Banten     82          1      45                  36
# 432 2021-05-12   Banten     56          0      24                  32
# 433 2021-05-13   Banten     34          0       1                  33
# 434 2021-05-14   Banten     39          0      15                  24
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  1                 1                    0
# 1                  1                 1                    0
# 2                  2                 4                    0
# 3                  2                 4                    0
# 4                  2                12                    0
# ..               ...               ...                  ...
# 430            48129             44961                 1223
# 431            48211             45006                 1224
# 432            48267             45030                 1224
# 433            48301             45031                 1224
# 434            48340             45046                 1224
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               0
# 1                               0
# 2                              -2
# 3                              -2
# 4                             -10
# ..                            ...
# 430                          1945
# 431                          1981
# 432                          2013
# 433                          2046
# 434                          2070
#
# [435 rows x 10 columns]

# %% [markdown]
# # DKI Jakarta

# %%
resp_dki = requests.get('https://data.covid19.go.id/public/api/prov_detail_DKI_JAKARTA.json')
resp_dki
# Out:
# <Response [200]>

# %%
prov_dki_raw = resp_dki.json()
prov_dki = prov_dki_raw['list_perkembangan']
prov_dki = pd.DataFrame(prov_dki)
prov_dki['tanggal'] = pd.to_datetime(prov_dki['tanggal']*1e6 ,unit='ns')
prov_dki.insert(1, 'provinsi', 'DKI Jakarta')
prov_dki
# Out:
#        tanggal     provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-01  DKI Jakarta      2          0       0                   2
# 1   2020-03-02  DKI Jakarta      2          0       0                   2
# 2   2020-03-03  DKI Jakarta      2          0       0                   2
# 3   2020-03-04  DKI Jakarta      2          0       0                   2
# 4   2020-03-05  DKI Jakarta      0          1       0                  -1
# ..         ...          ...    ...        ...     ...                 ...
# 435 2021-05-10  DKI Jakarta    694         22     607                  65
# 436 2021-05-11  DKI Jakarta    406         20     667                -281
# 437 2021-05-12  DKI Jakarta    656         13     674                 -31
# 438 2021-05-13  DKI Jakarta    785         15     585                 185
# 439 2021-05-14  DKI Jakarta    632         16     547                  69
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  2                 0                    0
# 1                  4                 0                    0
# 2                  6                 0                    0
# 3                  8                 0                    0
# 4                  8                 0                    1
# ..               ...               ...                  ...
# 435           416304            401606                 6826
# 436           416710            402273                 6846
# 437           417366            402947                 6859
# 438           418151            403532                 6874
# 439           418783            404079                 6890
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               2
# 1                               4
# 2                               6
# 3                               8
# 4                               7
# ..                            ...
# 435                          7872
# 436                          7591
# 437                          7560
# 438                          7745
# 439                          7814
#
# [440 rows x 10 columns]

# %%
prov_id = pd.concat([prov_banten, prov_dki], ignore_index=True)
prov_id
# Out:
#        tanggal     provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-06       Banten      1          0       1                   0
# 1   2020-03-07       Banten      0          0       0                   0
# 2   2020-03-08       Banten      1          0       3                  -2
# 3   2020-03-09       Banten      0          0       0                   0
# 4   2020-03-10       Banten      0          0       8                  -8
# ..         ...          ...    ...        ...     ...                 ...
# 870 2021-05-10  DKI Jakarta    694         22     607                  65
# 871 2021-05-11  DKI Jakarta    406         20     667                -281
# 872 2021-05-12  DKI Jakarta    656         13     674                 -31
# 873 2021-05-13  DKI Jakarta    785         15     585                 185
# 874 2021-05-14  DKI Jakarta    632         16     547                  69
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  1                 1                    0
# 1                  1                 1                    0
# 2                  2                 4                    0
# 3                  2                 4                    0
# 4                  2                12                    0
# ..               ...               ...                  ...
# 870           416304            401606                 6826
# 871           416710            402273                 6846
# 872           417366            402947                 6859
# 873           418151            403532                 6874
# 874           418783            404079                 6890
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               0
# 1                               0
# 2                              -2
# 3                              -2
# 4                             -10
# ..                            ...
# 870                          7872
# 871                          7591
# 872                          7560
# 873                          7745
# 874                          7814
#
# [875 rows x 10 columns]

# %% [markdown]
# # Jawa Barat

# %%
resp_jabar = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json')
resp_jabar
# Out:
# <Response [200]>

# %%
prov_jabar_raw = resp_jabar.json()
prov_jabar = prov_jabar_raw['list_perkembangan']
prov_jabar = pd.DataFrame(prov_jabar)
prov_jabar['tanggal'] = pd.to_datetime(prov_jabar['tanggal']*1e6 ,unit='ns')
prov_jabar.insert(1, 'provinsi', 'Jawa Barat')
prov_jabar
# Out:
#        tanggal    provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-02  Jawa Barat      3          0       0                   3
# 1   2020-03-03  Jawa Barat      1          1       0                   0
# 2   2020-03-04  Jawa Barat      1          0       0                   1
# 3   2020-03-05  Jawa Barat      1          0       0                   1
# 4   2020-03-06  Jawa Barat      1          0       0                   1
# ..         ...         ...    ...        ...     ...                 ...
# 434 2021-05-10  Jawa Barat   1070         16    2304               -1250
# 435 2021-05-11  Jawa Barat   1373         18    1073                 282
# 436 2021-05-12  Jawa Barat    814         22     769                  23
# 437 2021-05-13  Jawa Barat    400         10     602                -212
# 438 2021-05-14  Jawa Barat    610          2     685                 -77
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  3                 0                    0
# 1                  4                 0                    1
# 2                  5                 0                    1
# 3                  6                 0                    1
# 4                  7                 0                    1
# ..               ...               ...                  ...
# 434           292592            259600                 3887
# 435           293965            260673                 3905
# 436           294779            261442                 3927
# 437           295179            262044                 3937
# 438           295789            262729                 3939
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               3
# 1                               3
# 2                               4
# 3                               5
# 4                               6
# ..                            ...
# 434                         29105
# 435                         29387
# 436                         29410
# 437                         29198
# 438                         29121
#
# [439 rows x 10 columns]

# %%
prov_id = pd.concat([prov_id, prov_jabar], ignore_index=True)
prov_id
# Out:
#         tanggal    provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    2020-03-06      Banten      1          0       1                   0
# 1    2020-03-07      Banten      0          0       0                   0
# 2    2020-03-08      Banten      1          0       3                  -2
# 3    2020-03-09      Banten      0          0       0                   0
# 4    2020-03-10      Banten      0          0       8                  -8
# ...         ...         ...    ...        ...     ...                 ...
# 1309 2021-05-10  Jawa Barat   1070         16    2304               -1250
# 1310 2021-05-11  Jawa Barat   1373         18    1073                 282
# 1311 2021-05-12  Jawa Barat    814         22     769                  23
# 1312 2021-05-13  Jawa Barat    400         10     602                -212
# 1313 2021-05-14  Jawa Barat    610          2     685                 -77
#
#       AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                   1                 1                    0
# 1                   1                 1                    0
# 2                   2                 4                    0
# 3                   2                 4                    0
# 4                   2                12                    0
# ...               ...               ...                  ...
# 1309           292592            259600                 3887
# 1310           293965            260673                 3905
# 1311           294779            261442                 3927
# 1312           295179            262044                 3937
# 1313           295789            262729                 3939
#
#       AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                0
# 1                                0
# 2                               -2
# 3                               -2
# 4                              -10
# ...                            ...
# 1309                         29105
# 1310                         29387
# 1311                         29410
# 1312                         29198
# 1313                         29121
#
# [1314 rows x 10 columns]

# %% [markdown]
# # Jawa Tengah

# %%
resp_jateng = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_TENGAH.json')
resp_jateng
# Out:
# <Response [200]>

# %%
prov_jateng_raw = resp_jateng.json()
prov_jateng = prov_jateng_raw['list_perkembangan']
prov_jateng = pd.DataFrame(prov_jateng)
prov_jateng['tanggal'] = pd.to_datetime(prov_jateng['tanggal']*1e6 ,unit='ns')
prov_jateng.insert(1, 'provinsi', 'Jawa Tengah')
prov_jateng
# Out:
#        tanggal     provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-11  Jawa Tengah      1          1       0                   0
# 1   2020-03-12  Jawa Tengah      0          0       0                   0
# 2   2020-03-13  Jawa Tengah      0          0       0                   0
# 3   2020-03-14  Jawa Tengah      0          0       0                   0
# 4   2020-03-15  Jawa Tengah      0          0       0                   0
# ..         ...          ...    ...        ...     ...                 ...
# 425 2021-05-10  Jawa Tengah    854         76     744                  34
# 426 2021-05-11  Jawa Tengah    540         80     781                -321
# 427 2021-05-12  Jawa Tengah    109         24     292                -207
# 428 2021-05-13  Jawa Tengah    480          1    1146                -667
# 429 2021-05-14  Jawa Tengah    162         24     448                -310
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  1                 0                    1
# 1                  1                 0                    1
# 2                  1                 0                    1
# 3                  1                 0                    1
# 4                  1                 0                    1
# ..               ...               ...                  ...
# 425           188065            170644                 8549
# 426           188605            171425                 8629
# 427           188714            171717                 8653
# 428           189194            172863                 8654
# 429           189356            173311                 8678
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 425                          8872
# 426                          8551
# 427                          8344
# 428                          7677
# 429                          7367
#
# [430 rows x 10 columns]

# %%
prov_id = pd.concat([prov_id, prov_jateng], ignore_index=True)
prov_id
# Out:
#         tanggal     provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    2020-03-06       Banten      1          0       1                   0
# 1    2020-03-07       Banten      0          0       0                   0
# 2    2020-03-08       Banten      1          0       3                  -2
# 3    2020-03-09       Banten      0          0       0                   0
# 4    2020-03-10       Banten      0          0       8                  -8
# ...         ...          ...    ...        ...     ...                 ...
# 1739 2021-05-10  Jawa Tengah    854         76     744                  34
# 1740 2021-05-11  Jawa Tengah    540         80     781                -321
# 1741 2021-05-12  Jawa Tengah    109         24     292                -207
# 1742 2021-05-13  Jawa Tengah    480          1    1146                -667
# 1743 2021-05-14  Jawa Tengah    162         24     448                -310
#
#       AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                   1                 1                    0
# 1                   1                 1                    0
# 2                   2                 4                    0
# 3                   2                 4                    0
# 4                   2                12                    0
# ...               ...               ...                  ...
# 1739           188065            170644                 8549
# 1740           188605            171425                 8629
# 1741           188714            171717                 8653
# 1742           189194            172863                 8654
# 1743           189356            173311                 8678
#
#       AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                0
# 1                                0
# 2                               -2
# 3                               -2
# 4                              -10
# ...                            ...
# 1739                          8872
# 1740                          8551
# 1741                          8344
# 1742                          7677
# 1743                          7367
#
# [1744 rows x 10 columns]

# %% [markdown]
# # DIY

# %%
resp_diy = requests.get('https://data.covid19.go.id/public/api/prov_detail_DAERAH_ISTIMEWA_YOGYAKARTA.json')
resp_diy
# Out:
# <Response [200]>

# %%
prov_diy_raw = resp_diy.json()
prov_diy = prov_diy_raw['list_perkembangan']
prov_diy = pd.DataFrame(prov_diy)
prov_diy['tanggal'] = pd.to_datetime(prov_diy['tanggal']*1e6 ,unit='ns')
prov_diy.insert(1, 'provinsi', 'Daerah istimewa Yogyakarta')
prov_diy
# Out:
#        tanggal                    provinsi  KASUS  MENINGGAL  SEMBUH  \
# 0   2020-03-16  Daerah istimewa Yogyakarta      1          0       0
# 1   2020-03-17  Daerah istimewa Yogyakarta      0          0       0
# 2   2020-03-18  Daerah istimewa Yogyakarta      0          0       0
# 3   2020-03-19  Daerah istimewa Yogyakarta      0          0       0
# 4   2020-03-20  Daerah istimewa Yogyakarta      1          0       1
# ..         ...                         ...    ...        ...     ...
# 420 2021-05-10  Daerah istimewa Yogyakarta    142          5     215
# 421 2021-05-11  Daerah istimewa Yogyakarta    154          5     307
# 422 2021-05-12  Daerah istimewa Yogyakarta    217          8     232
# 423 2021-05-13  Daerah istimewa Yogyakarta    105          4     240
# 424 2021-05-14  Daerah istimewa Yogyakarta     97         13     165
#
#      DIRAWAT_OR_ISOLASI  AKUMULASI_KASUS  AKUMULASI_SEMBUH  \
# 0                     1                1                 0
# 1                     0                1                 0
# 2                     0                1                 0
# 3                     0                1                 0
# 4                     0                2                 1
# ..                  ...              ...               ...
# 420                 -78            41204             37158
# 421                -158            41358             37465
# 422                 -23            41575             37697
# 423                -139            41680             37937
# 424                 -81            41777             38102
#
#      AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                      0                             1
# 1                      0                             1
# 2                      0                             1
# 3                      0                             1
# 4                      0                             1
# ..                   ...                           ...
# 420                 1028                          3018
# 421                 1033                          2860
# 422                 1041                          2837
# 423                 1045                          2698
# 424                 1058                          2617
#
# [425 rows x 10 columns]

# %%
prov_id = pd.concat([prov_id, prov_diy], ignore_index=True)
prov_id
# Out:
#         tanggal                    provinsi  KASUS  MENINGGAL  SEMBUH  \
# 0    2020-03-06                      Banten      1          0       1
# 1    2020-03-07                      Banten      0          0       0
# 2    2020-03-08                      Banten      1          0       3
# 3    2020-03-09                      Banten      0          0       0
# 4    2020-03-10                      Banten      0          0       8
# ...         ...                         ...    ...        ...     ...
# 2164 2021-05-10  Daerah istimewa Yogyakarta    142          5     215
# 2165 2021-05-11  Daerah istimewa Yogyakarta    154          5     307
# 2166 2021-05-12  Daerah istimewa Yogyakarta    217          8     232
# 2167 2021-05-13  Daerah istimewa Yogyakarta    105          4     240
# 2168 2021-05-14  Daerah istimewa Yogyakarta     97         13     165
#
#       DIRAWAT_OR_ISOLASI  AKUMULASI_KASUS  AKUMULASI_SEMBUH  \
# 0                      0                1                 1
# 1                      0                1                 1
# 2                     -2                2                 4
# 3                      0                2                 4
# 4                     -8                2                12
# ...                  ...              ...               ...
# 2164                 -78            41204             37158
# 2165                -158            41358             37465
# 2166                 -23            41575             37697
# 2167                -139            41680             37937
# 2168                 -81            41777             38102
#
#       AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                       0                             0
# 1                       0                             0
# 2                       0                            -2
# 3                       0                            -2
# 4                       0                           -10
# ...                   ...                           ...
# 2164                 1028                          3018
# 2165                 1033                          2860
# 2166                 1041                          2837
# 2167                 1045                          2698
# 2168                 1058                          2617
#
# [2169 rows x 10 columns]

# %% [markdown]
# # Jawa Timur

# %%
resp_jatim = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_TIMUR.json')
resp_jatim
# Out:
# <Response [200]>

# %%
prov_jatim_raw = resp_jatim.json()
prov_jatim = prov_jatim_raw['list_perkembangan']
prov_jatim = pd.DataFrame(prov_jatim)
prov_jatim['tanggal'] = pd.to_datetime(prov_jatim['tanggal']*1e6 ,unit='ns')
prov_jatim.insert(1, 'provinsi', 'Jawa Timur')
prov_jatim
# Out:
#        tanggal    provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-01-08  Jawa Timur      9          3       1                   5
# 1   2020-01-09  Jawa Timur      0          1      23                 -24
# 2   2020-01-10  Jawa Timur      0          1      14                 -15
# 3   2020-01-11  Jawa Timur      0          3       8                 -11
# 4   2020-01-12  Jawa Timur      0          3       1                  -4
# ..         ...         ...    ...        ...     ...                 ...
# 488 2021-05-10  Jawa Timur    206         21     213                 -28
# 489 2021-05-11  Jawa Timur    258         31     192                  35
# 490 2021-05-12  Jawa Timur    248         22     224                   2
# 491 2021-05-13  Jawa Timur    148         12     151                 -15
# 492 2021-05-14  Jawa Timur    141         15     174                 -48
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  9                 1                    3
# 1                  9                24                    4
# 2                  9                38                    5
# 3                  9                46                    8
# 4                  9                47                   11
# ..               ...               ...                  ...
# 488           150106            137134                10894
# 489           150364            137326                10925
# 490           150612            137550                10947
# 491           150760            137701                10959
# 492           150901            137875                10974
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               5
# 1                             -19
# 2                             -34
# 3                             -45
# 4                             -49
# ..                            ...
# 488                          2078
# 489                          2113
# 490                          2115
# 491                          2100
# 492                          2052
#
# [493 rows x 10 columns]

# %%
prov_id = pd.concat([prov_id, prov_jatim], ignore_index=True)
prov_id
# Out:
#         tanggal    provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    2020-03-06      Banten      1          0       1                   0
# 1    2020-03-07      Banten      0          0       0                   0
# 2    2020-03-08      Banten      1          0       3                  -2
# 3    2020-03-09      Banten      0          0       0                   0
# 4    2020-03-10      Banten      0          0       8                  -8
# ...         ...         ...    ...        ...     ...                 ...
# 2657 2021-05-10  Jawa Timur    206         21     213                 -28
# 2658 2021-05-11  Jawa Timur    258         31     192                  35
# 2659 2021-05-12  Jawa Timur    248         22     224                   2
# 2660 2021-05-13  Jawa Timur    148         12     151                 -15
# 2661 2021-05-14  Jawa Timur    141         15     174                 -48
#
#       AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                   1                 1                    0
# 1                   1                 1                    0
# 2                   2                 4                    0
# 3                   2                 4                    0
# 4                   2                12                    0
# ...               ...               ...                  ...
# 2657           150106            137134                10894
# 2658           150364            137326                10925
# 2659           150612            137550                10947
# 2660           150760            137701                10959
# 2661           150901            137875                10974
#
#       AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                0
# 1                                0
# 2                               -2
# 3                               -2
# 4                              -10
# ...                            ...
# 2657                          2078
# 2658                          2113
# 2659                          2115
# 2660                          2100
# 2661                          2052
#
# [2662 rows x 10 columns]

# %% [markdown]
# # Bali

# %%
resp_bali = requests.get('https://data.covid19.go.id/public/api/prov_detail_BALI.json')
resp_bali
# Out:
# <Response [200]>

# %%
prov_bali_raw = resp_bali.json()
prov_bali = prov_bali_raw['list_perkembangan']
prov_bali = pd.DataFrame(prov_bali)
prov_bali['tanggal'] = pd.to_datetime(prov_bali['tanggal']*1e6 ,unit='ns')
prov_bali.insert(1, 'provinsi', 'Bali')
prov_bali
# Out:
#        tanggal provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0   2020-03-11     Bali      1          1       0                   0
# 1   2020-03-12     Bali      0          0       0                   0
# 2   2020-03-13     Bali      0          0       0                   0
# 3   2020-03-14     Bali      0          0       0                   0
# 4   2020-03-15     Bali      0          0       0                   0
# ..         ...      ...    ...        ...     ...                 ...
# 425 2021-05-10     Bali     74          7     117                 -50
# 426 2021-05-11     Bali    101         11      93                  -3
# 427 2021-05-12     Bali     97          3      97                  -3
# 428 2021-05-13     Bali     94          5      73                  16
# 429 2021-05-14     Bali     47          3      98                 -54
#
#      AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                  1                 0                    1
# 1                  1                 0                    1
# 2                  1                 0                    1
# 3                  1                 0                    1
# 4                  1                 0                    1
# ..               ...               ...                  ...
# 425            45829             42910                 1286
# 426            45930             43003                 1297
# 427            46027             43100                 1300
# 428            46121             43173                 1305
# 429            46168             43271                 1308
#
#      AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 425                          1633
# 426                          1630
# 427                          1627
# 428                          1643
# 429                          1589
#
# [430 rows x 10 columns]

# %%
prov_id = pd.concat([prov_id, prov_bali], ignore_index=True)
prov_id
# Out:
#         tanggal provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    2020-03-06   Banten      1          0       1                   0
# 1    2020-03-07   Banten      0          0       0                   0
# 2    2020-03-08   Banten      1          0       3                  -2
# 3    2020-03-09   Banten      0          0       0                   0
# 4    2020-03-10   Banten      0          0       8                  -8
# ...         ...      ...    ...        ...     ...                 ...
# 3087 2021-05-10     Bali     74          7     117                 -50
# 3088 2021-05-11     Bali    101         11      93                  -3
# 3089 2021-05-12     Bali     97          3      97                  -3
# 3090 2021-05-13     Bali     94          5      73                  16
# 3091 2021-05-14     Bali     47          3      98                 -54
#
#       AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                   1                 1                    0
# 1                   1                 1                    0
# 2                   2                 4                    0
# 3                   2                 4                    0
# 4                   2                12                    0
# ...               ...               ...                  ...
# 3087            45829             42910                 1286
# 3088            45930             43003                 1297
# 3089            46027             43100                 1300
# 3090            46121             43173                 1305
# 3091            46168             43271                 1308
#
#       AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                0
# 1                                0
# 2                               -2
# 3                               -2
# 4                              -10
# ...                            ...
# 3087                          1633
# 3088                          1630
# 3089                          1627
# 3090                          1643
# 3091                          1589
#
# [3092 rows x 10 columns]

# %% [markdown]
# # NUSA TENGGARA BARAT
# # NUSA TENGGARA TIMUR

# %%
resp_ntb = requests.get('https://data.covid19.go.id/public/api/prov_detail_NUSA_TENGGARA_BARAT.json')
resp_ntt = requests.get('https://data.covid19.go.id/public/api/prov_detail_NUSA_TENGGARA_TIMUR.json')
print(resp_ntb)
print(resp_ntt)
# Out:
# <Response [200]>
# <Response [200]>

# %%
#ntb
prov_ntb_raw = resp_ntb.json()
prov_ntb = prov_ntb_raw['list_perkembangan']
prov_ntb = pd.DataFrame(prov_ntb)
prov_ntb['tanggal'] = pd.to_datetime(prov_ntb['tanggal']*1e6 ,unit='ns')
prov_ntb.insert(1, 'provinsi', 'Nusa Tenggara Barat')

#ntt
prov_ntt_raw = resp_ntt.json()
prov_ntt = prov_ntt_raw['list_perkembangan']
prov_ntt = pd.DataFrame(prov_ntt)
prov_ntt['tanggal'] = pd.to_datetime(prov_ntt['tanggal']*1e6 ,unit='ns')
prov_ntt.insert(1, 'provinsi', 'Nusa Tenggara Timur')

# %%
ntt_ntb = [prov_id, prov_ntb, prov_ntt]

prov_id = pd.concat(ntt_ntb, ignore_index=True)
prov_id
# Out:
#         tanggal             provinsi  KASUS  MENINGGAL  SEMBUH  \
# 0    2020-03-06               Banten      1          0       1
# 1    2020-03-07               Banten      0          0       0
# 2    2020-03-08               Banten      1          0       3
# 3    2020-03-09               Banten      0          0       0
# 4    2020-03-10               Banten      0          0       8
# ...         ...                  ...    ...        ...     ...
# 3898 2021-05-10  Nusa Tenggara Timur     60          0      68
# 3899 2021-05-11  Nusa Tenggara Timur    125          1     167
# 3900 2021-05-12  Nusa Tenggara Timur      9          1       1
# 3901 2021-05-13  Nusa Tenggara Timur      4          6      49
# 3902 2021-05-14  Nusa Tenggara Timur     77          1      75
#
#       DIRAWAT_OR_ISOLASI  AKUMULASI_KASUS  AKUMULASI_SEMBUH  \
# 0                      0                1                 1
# 1                      0                1                 1
# 2                     -2                2                 4
# 3                      0                2                 4
# 4                     -8                2                12
# ...                  ...              ...               ...
# 3898                  -8            15362             13364
# 3899                 -43            15487             13531
# 3900                   7            15496             13532
# 3901                 -51            15500             13581
# 3902                   1            15577             13656
#
#       AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                       0                             0
# 1                       0                             0
# 2                       0                            -2
# 3                       0                            -2
# 4                       0                           -10
# ...                   ...                           ...
# 3898                  395                          1603
# 3899                  396                          1560
# 3900                  397                          1567
# 3901                  403                          1516
# 3902                  404                          1517
#
# [3903 rows x 10 columns]

# %% [markdown]
# # Sumatera
# - Aceh
# - Sumut
# - Sumbar
# - Riau
# - Kepri
# - Jambi
# - Bengkulu
# - Sulsel
# - Kep. Balbel
# - Lampung

# %%
resp_aceh = requests.get('https://data.covid19.go.id/public/api/prov_detail_ACEH.json')
resp_sumut = requests.get('https://data.covid19.go.id/public/api/prov_detail_SUMATERA_UTARA.json')
resp_sumbar = requests.get('https://data.covid19.go.id/public/api/prov_detail_SUMATERA_BARAT.json')
resp_riau = requests.get('https://data.covid19.go.id/public/api/prov_detail_RIAU.json')
resp_kepri = requests.get('https://data.covid19.go.id/public/api/prov_detail_KEPULAUAN_RIAU.json')
resp_jambi = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAMBI.json')
resp_bengkulu = requests.get('https://data.covid19.go.id/public/api/prov_detail_BENGKULU.json')
resp_sumsel = requests.get('https://data.covid19.go.id/public/api/prov_detail_SUMATERA_SELATAN.json')
resp_balbel = requests.get('https://data.covid19.go.id/public/api/prov_detail_KEPULAUAN_BANGKA_BELITUNG.json')
resp_lampung = requests.get('https://data.covid19.go.id/public/api/prov_detail_LAMPUNG.json')
print(resp_aceh)
print(resp_sumut)
print(resp_sumbar)
print(resp_riau)
print(resp_kepri)
print(resp_jambi)
print(resp_bengkulu)
print(resp_sumsel)
print(resp_balbel)
print(resp_lampung)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#aceh
prov_aceh_raw = resp_aceh.json()
prov_aceh = prov_aceh_raw['list_perkembangan']
prov_aceh = pd.DataFrame(prov_aceh)
prov_aceh['tanggal'] = pd.to_datetime(prov_aceh['tanggal']*1e6 ,unit='ns')
prov_aceh.insert(1, 'provinsi', 'Aceh')

#sumut
prov_sumut_raw = resp_sumut.json()
prov_sumut = prov_sumut_raw['list_perkembangan']
prov_sumut = pd.DataFrame(prov_sumut)
prov_sumut['tanggal'] = pd.to_datetime(prov_sumut['tanggal']*1e6 ,unit='ns')
prov_sumut.insert(1, 'provinsi', 'Sumatera Utara')

#sumbar
prov_sumbar_raw = resp_sumbar.json()
prov_sumbar = prov_sumbar_raw['list_perkembangan']
prov_sumbar = pd.DataFrame(prov_sumbar)
prov_sumbar['tanggal'] = pd.to_datetime(prov_sumbar['tanggal']*1e6 ,unit='ns')
prov_sumbar.insert(1, 'provinsi', 'Sumatera Barat')

#riau
prov_riau_raw = resp_riau.json()
prov_riau = prov_riau_raw['list_perkembangan']
prov_riau = pd.DataFrame(prov_riau)
prov_riau['tanggal'] = pd.to_datetime(prov_riau['tanggal']*1e6 ,unit='ns')
prov_riau.insert(1, 'provinsi', 'Riau')

#kepri
prov_kepri_raw = resp_kepri.json()
prov_kepri = prov_kepri_raw['list_perkembangan']
prov_kepri = pd.DataFrame(prov_kepri)
prov_kepri['tanggal'] = pd.to_datetime(prov_kepri['tanggal']*1e6 ,unit='ns')
prov_kepri.insert(1, 'provinsi', 'Kepulauan Riau')

#jambi
prov_jambi_raw = resp_jambi.json()
prov_jambi = prov_jambi_raw['list_perkembangan']
prov_jambi = pd.DataFrame(prov_jambi)
prov_jambi['tanggal'] = pd.to_datetime(prov_jambi['tanggal']*1e6 ,unit='ns')
prov_jambi.insert(1, 'provinsi', 'Jambi')

#bengkulu
prov_bengkulu_raw = resp_bengkulu.json()
prov_bengkulu = prov_bengkulu_raw['list_perkembangan']
prov_bengkulu = pd.DataFrame(prov_bengkulu)
prov_bengkulu['tanggal'] = pd.to_datetime(prov_bengkulu['tanggal']*1e6 ,unit='ns')
prov_bengkulu.insert(1, 'provinsi', 'Bengkulu')

#sumsel
prov_sumsel_raw = resp_sumsel.json()
prov_sumsel = prov_sumsel_raw['list_perkembangan']
prov_sumsel = pd.DataFrame(prov_sumsel)
prov_sumsel['tanggal'] = pd.to_datetime(prov_sumsel['tanggal']*1e6 ,unit='ns')
prov_sumsel.insert(1, 'provinsi', 'Sumatera Selatan')

#balbel
prov_balbel_raw = resp_balbel.json()
prov_balbel = prov_balbel_raw['list_perkembangan']
prov_balbel = pd.DataFrame(prov_balbel)
prov_balbel['tanggal'] = pd.to_datetime(prov_balbel['tanggal']*1e6 ,unit='ns')
prov_balbel.insert(1, 'provinsi', 'Kep. Bangka Belitung')

#lampung
prov_lampung_raw = resp_lampung.json()
prov_lampung = prov_lampung_raw['list_perkembangan']
prov_lampung = pd.DataFrame(prov_lampung)
prov_lampung['tanggal'] = pd.to_datetime(prov_lampung['tanggal']*1e6 ,unit='ns')
prov_lampung.insert(1, 'provinsi', 'Lampung')

# %%
sumatera = [prov_id, prov_aceh, prov_sumut, prov_sumbar, prov_riau,
           prov_kepri, prov_jambi, prov_bengkulu, prov_sumsel, prov_balbel, prov_lampung]

prov_id = pd.concat(sumatera, ignore_index=True)
prov_id
# Out:
#         tanggal provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0    2020-03-06   Banten      1          0       1                   0
# 1    2020-03-07   Banten      0          0       0                   0
# 2    2020-03-08   Banten      1          0       3                  -2
# 3    2020-03-09   Banten      0          0       0                   0
# 4    2020-03-10   Banten      0          0       8                  -8
# ...         ...      ...    ...        ...     ...                 ...
# 8087 2021-05-10  Lampung     44          1      48                  -5
# 8088 2021-05-11  Lampung     85         18     217                -150
# 8089 2021-05-12  Lampung     88          5      72                  11
# 8090 2021-05-13  Lampung     49          4      25                  20
# 8091 2021-05-14  Lampung     29          2      34                  -7
#
#       AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                   1                 1                    0
# 1                   1                 1                    0
# 2                   2                 4                    0
# 3                   2                 4                    0
# 4                   2                12                    0
# ...               ...               ...                  ...
# 8087            16635             14345                  837
# 8088            16720             14562                  855
# 8089            16808             14634                  860
# 8090            16857             14659                  864
# 8091            16886             14693                  866
#
#       AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                0
# 1                                0
# 2                               -2
# 3                               -2
# 4                              -10
# ...                            ...
# 8087                          1453
# 8088                          1303
# 8089                          1314
# 8090                          1334
# 8091                          1327
#
# [8092 rows x 10 columns]

# %% [markdown]
# # Kalimantan

# %%
resp_kalbar = requests.get('https://data.covid19.go.id/public/api/prov_detail_KALIMANTAN_BARAT.json')
resp_kalsel = requests.get('https://data.covid19.go.id/public/api/prov_detail_KALIMANTAN_SELATAN.json')
resp_kalteng = requests.get('https://data.covid19.go.id/public/api/prov_detail_KALIMANTAN_TENGAH.json')
resp_kaltim = requests.get('https://data.covid19.go.id/public/api/prov_detail_KALIMANTAN_TIMUR.json')
resp_kalut = requests.get('https://data.covid19.go.id/public/api/prov_detail_KALIMANTAN_UTARA.json')
print(resp_kalbar)
print(resp_kalsel)
print(resp_kalteng)
print(resp_kaltim)
print(resp_kalut)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#kalbar
prov_kalbar_raw = resp_kalbar.json()
prov_kalbar = prov_kalbar_raw['list_perkembangan']
prov_kalbar = pd.DataFrame(prov_kalbar)
prov_kalbar['tanggal'] = pd.to_datetime(prov_kalbar['tanggal']*1e6 ,unit='ns')
prov_kalbar.insert(1, 'provinsi', 'Kalimantan Barat')

#kalsel
prov_kalsel_raw = resp_kalsel.json()
prov_kalsel = prov_kalsel_raw['list_perkembangan']
prov_kalsel = pd.DataFrame(prov_kalsel)
prov_kalsel['tanggal'] = pd.to_datetime(prov_kalsel['tanggal']*1e6 ,unit='ns')
prov_kalsel.insert(1, 'provinsi', 'Kalimantan Selatan')

#kalteng
prov_kalteng_raw = resp_kalteng.json()
prov_kalteng = prov_kalteng_raw['list_perkembangan']
prov_kalteng = pd.DataFrame(prov_kalteng)
prov_kalteng['tanggal'] = pd.to_datetime(prov_kalteng['tanggal']*1e6 ,unit='ns')
prov_kalteng.insert(1, 'provinsi', 'Kalimantan Tengah')

#kaltim
prov_kaltim_raw = resp_kaltim.json()
prov_kaltim = prov_kaltim_raw['list_perkembangan']
prov_kaltim = pd.DataFrame(prov_kaltim)
prov_kaltim['tanggal'] = pd.to_datetime(prov_kaltim['tanggal']*1e6 ,unit='ns')
prov_kaltim.insert(1, 'provinsi', 'Kalimantan Timur')

#kalut
prov_kalut_raw = resp_kalut.json()
prov_kalut = prov_kalut_raw['list_perkembangan']
prov_kalut = pd.DataFrame(prov_kalut)
prov_kalut['tanggal'] = pd.to_datetime(prov_kalut['tanggal']*1e6 ,unit='ns')
prov_kalut.insert(1, 'provinsi', 'kalimantan Utara')

# %%
kalimantan = [prov_id, prov_kalbar, prov_kalsel, prov_kalteng, prov_kaltim, prov_kalut]

prov_id = pd.concat(kalimantan, ignore_index=True)
prov_id
# Out:
#          tanggal          provinsi  KASUS  MENINGGAL  SEMBUH  \
# 0     2020-03-06            Banten      1          0       1
# 1     2020-03-07            Banten      0          0       0
# 2     2020-03-08            Banten      1          0       3
# 3     2020-03-09            Banten      0          0       0
# 4     2020-03-10            Banten      0          0       8
# ...          ...               ...    ...        ...     ...
# 10165 2021-05-10  kalimantan Utara      4          0      28
# 10166 2021-05-11  kalimantan Utara     11          0      39
# 10167 2021-05-12  kalimantan Utara      0          0       4
# 10168 2021-05-13  kalimantan Utara      0          0       0
# 10169 2021-05-14  kalimantan Utara      9          0       0
#
#        DIRAWAT_OR_ISOLASI  AKUMULASI_KASUS  AKUMULASI_SEMBUH  \
# 0                       0                1                 1
# 1                       0                1                 1
# 2                      -2                2                 4
# 3                       0                2                 4
# 4                      -8                2                12
# ...                   ...              ...               ...
# 10165                 -24            11871             11201
# 10166                 -28            11882             11240
# 10167                  -4            11882             11244
# 10168                   0            11882             11244
# 10169                   9            11891             11244
#
#        AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                        0                             0
# 1                        0                             0
# 2                        0                            -2
# 3                        0                            -2
# 4                        0                           -10
# ...                    ...                           ...
# 10165                  188                           482
# 10166                  188                           454
# 10167                  188                           450
# 10168                  188                           450
# 10169                  188                           459
#
# [10170 rows x 10 columns]

# %% [markdown]
# # Sulawesi

# %%
resp_gorontalo = requests.get('https://data.covid19.go.id/public/api/prov_detail_GORONTALO.json')
resp_sulbar = requests.get('https://data.covid19.go.id/public/api/prov_detail_SULAWESI_BARAT.json')
resp_sulsel = requests.get('https://data.covid19.go.id/public/api/prov_detail_SULAWESI_SELATAN.json')
resp_sulteng = requests.get('https://data.covid19.go.id/public/api/prov_detail_SULAWESI_TENGAH.json')
resp_sultengg = requests.get('https://data.covid19.go.id/public/api/prov_detail_SULAWESI_TENGGARA.json')
resp_sulut = requests.get('https://data.covid19.go.id/public/api/prov_detail_SULAWESI_UTARA.json')
print(resp_gorontalo)
print(resp_sulbar)
print(resp_sulsel)
print(resp_sulteng)
print(resp_sultengg)
print(resp_sulut)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#gorontalo
prov_gorontalo_raw = resp_gorontalo.json()
prov_gorontalo = prov_gorontalo_raw['list_perkembangan']
prov_gorontalo = pd.DataFrame(prov_gorontalo)
prov_gorontalo['tanggal'] = pd.to_datetime(prov_gorontalo['tanggal']*1e6 ,unit='ns')
prov_gorontalo.insert(1, 'provinsi', 'Gorontalo')

#sulbar
prov_sulbar_raw = resp_sulbar.json()
prov_sulbar = prov_sulbar_raw['list_perkembangan']
prov_sulbar = pd.DataFrame(prov_sulbar)
prov_sulbar['tanggal'] = pd.to_datetime(prov_sulbar['tanggal']*1e6 ,unit='ns')
prov_sulbar.insert(1, 'provinsi', 'Sulawesi Barat')

#sulsel
prov_sulsel_raw = resp_sulsel.json()
prov_sulsel = prov_sulsel_raw['list_perkembangan']
prov_sulsel = pd.DataFrame(prov_sulsel)
prov_sulsel['tanggal'] = pd.to_datetime(prov_sulsel['tanggal']*1e6 ,unit='ns')
prov_sulsel.insert(1, 'provinsi', 'Sulawesi Selatan')

#sulteng
prov_sulteng_raw = resp_sulteng.json()
prov_sulteng = prov_sulteng_raw['list_perkembangan']
prov_sulteng = pd.DataFrame(prov_sulteng)
prov_sulteng['tanggal'] = pd.to_datetime(prov_sulteng['tanggal']*1e6 ,unit='ns')
prov_sulteng.insert(1, 'provinsi', 'Sulawesi Tengah')

#sultengg
prov_sultengg_raw = resp_sultengg.json()
prov_sultengg = prov_sultengg_raw['list_perkembangan']
prov_sultengg = pd.DataFrame(prov_sultengg)
prov_sultengg['tanggal'] = pd.to_datetime(prov_sultengg['tanggal']*1e6 ,unit='ns')
prov_sultengg.insert(1, 'provinsi', 'Sulawesi Tenggara')

#sulut
prov_sulut_raw = resp_sulut.json()
prov_sulut = prov_sulut_raw['list_perkembangan']
prov_sulut = pd.DataFrame(prov_sulut)
prov_sulut['tanggal'] = pd.to_datetime(prov_sulut['tanggal']*1e6 ,unit='ns')
prov_sulut.insert(1, 'provinsi', 'Sulawesi Utara')

# %%
sulawesi = [prov_id, prov_gorontalo, prov_sulbar, prov_sulsel, 
            prov_sulut, prov_sulteng, prov_sultengg]

prov_id = pd.concat(kalimantan, ignore_index=True)
prov_id
# Out:
#          tanggal          provinsi  KASUS  MENINGGAL  SEMBUH  \
# 0     2020-03-06            Banten      1          0       1
# 1     2020-03-07            Banten      0          0       0
# 2     2020-03-08            Banten      1          0       3
# 3     2020-03-09            Banten      0          0       0
# 4     2020-03-10            Banten      0          0       8
# ...          ...               ...    ...        ...     ...
# 10165 2021-05-10  kalimantan Utara      4          0      28
# 10166 2021-05-11  kalimantan Utara     11          0      39
# 10167 2021-05-12  kalimantan Utara      0          0       4
# 10168 2021-05-13  kalimantan Utara      0          0       0
# 10169 2021-05-14  kalimantan Utara      9          0       0
#
#        DIRAWAT_OR_ISOLASI  AKUMULASI_KASUS  AKUMULASI_SEMBUH  \
# 0                       0                1                 1
# 1                       0                1                 1
# 2                      -2                2                 4
# 3                       0                2                 4
# 4                      -8                2                12
# ...                   ...              ...               ...
# 10165                 -24            11871             11201
# 10166                 -28            11882             11240
# 10167                  -4            11882             11244
# 10168                   0            11882             11244
# 10169                   9            11891             11244
#
#        AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                        0                             0
# 1                        0                             0
# 2                        0                            -2
# 3                        0                            -2
# 4                        0                           -10
# ...                    ...                           ...
# 10165                  188                           482
# 10166                  188                           454
# 10167                  188                           450
# 10168                  188                           450
# 10169                  188                           459
#
# [10170 rows x 10 columns]

# %% [markdown]
# # Papua

# %%
resp_maluku = requests.get('https://data.covid19.go.id/public/api/prov_detail_MALUKU.json')
resp_malut = requests.get('https://data.covid19.go.id/public/api/prov_detail_MALUKU_UTARA.json')
resp_papbar = requests.get('https://data.covid19.go.id/public/api/prov_detail_PAPUA_BARAT.json')
resp_papua = requests.get('https://data.covid19.go.id/public/api/prov_detail_PAPUA.json')
print(resp_maluku)
print(resp_malut)
print(resp_papbar)
print(resp_papua)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#maluku
prov_maluku_raw = resp_maluku.json()
prov_maluku = prov_maluku_raw['list_perkembangan']
prov_maluku = pd.DataFrame(prov_maluku)
prov_maluku['tanggal'] = pd.to_datetime(prov_maluku['tanggal']*1e6 ,unit='ns')
prov_maluku.insert(1, 'provinsi', 'Maluku')

#malut
prov_malut_raw = resp_malut.json()
prov_malut = prov_malut_raw['list_perkembangan']
prov_malut = pd.DataFrame(prov_malut)
prov_malut['tanggal'] = pd.to_datetime(prov_malut['tanggal']*1e6 ,unit='ns')
prov_malut.insert(1, 'provinsi', 'Maluku Utara')

#papbar
prov_papbar_raw = resp_papbar.json()
prov_papbar = prov_papbar_raw['list_perkembangan']
prov_papbar = pd.DataFrame(prov_papbar)
prov_papbar['tanggal'] = pd.to_datetime(prov_papbar['tanggal']*1e6 ,unit='ns')
prov_papbar.insert(1, 'provinsi', 'Papua Barat')

#papua
prov_papua_raw = resp_papua.json()
prov_papua = prov_papua_raw['list_perkembangan']
prov_papua = pd.DataFrame(prov_papua)
prov_papua['tanggal'] = pd.to_datetime(prov_papua['tanggal']*1e6 ,unit='ns')
prov_papua.insert(1, 'provinsi', 'Papua')

# %%
papua = [prov_id, prov_maluku, prov_malut, prov_papbar, prov_papua]

prov_id = pd.concat(papua, ignore_index=True)
prov_id
# Out:
#          tanggal provinsi  KASUS  MENINGGAL  SEMBUH  DIRAWAT_OR_ISOLASI  \
# 0     2020-03-06   Banten      1          0       1                   0
# 1     2020-03-07   Banten      0          0       0                   0
# 2     2020-03-08   Banten      1          0       3                  -2
# 3     2020-03-09   Banten      0          0       0                   0
# 4     2020-03-10   Banten      0          0       8                  -8
# ...          ...      ...    ...        ...     ...                 ...
# 11832 2021-05-08    Papua      1          0       4                  -3
# 11833 2021-05-09    Papua     17          0      18                  -1
# 11834 2021-05-10    Papua      0          0       0                   0
# 11835 2021-05-11    Papua      2          0      18                 -16
# 11836 2021-05-12    Papua      3          0       6                  -3
#
#        AKUMULASI_KASUS  AKUMULASI_SEMBUH  AKUMULASI_MENINGGAL  \
# 0                    1                 1                    0
# 1                    1                 1                    0
# 2                    2                 4                    0
# 3                    2                 4                    0
# 4                    2                12                    0
# ...                ...               ...                  ...
# 11832            20411             11404                  207
# 11833            20428             11422                  207
# 11834            20428             11422                  207
# 11835            20430             11440                  207
# 11836            20433             11446                  207
#
#        AKUMULASI_DIRAWAT_OR_ISOLASI
# 0                                 0
# 1                                 0
# 2                                -2
# 3                                -2
# 4                               -10
# ...                             ...
# 11832                          8800
# 11833                          8799
# 11834                          8799
# 11835                          8783
# 11836                          8780
#
# [11837 rows x 10 columns]

# %% [markdown]
# # Upload to Google Sheet

# %%
# !pip3 install gspread
# !pip3 install --upgrade google-api-python-client oauth2client
# Out:
# Requirement already satisfied: gspread in c:\users\acer\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\acer\anaconda3\lib\site-packages (from gspread) (0.4.4)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\acer\anaconda3\lib\site-packages (from gspread) (1.30.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (52.0.0.post20210125)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\acer\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: requests>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\acer\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.4)
# Requirement already satisfied: google-api-python-client in c:\users\acer\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: oauth2client in c:\users\acer\anaconda3\lib\site-packages (4.1.3)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (1.26.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.13.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: google-auth<2dev,>=1.16.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (1.30.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (0.19.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: pytz in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2021.1)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (3.16.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (20.9)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (52.0.0.post20210125)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (1.53.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\acer\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2.25.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\acer\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\acer\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.10)

# %%
# !pip3 install gspread-dataframe
# Out:
# Requirement already satisfied: gspread-dataframe in c:\users\acer\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: gspread>=3.0.0 in c:\users\acer\anaconda3\lib\site-packages (from gspread-dataframe) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\acer\anaconda3\lib\site-packages (from gspread-dataframe) (1.15.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\acer\anaconda3\lib\site-packages (from gspread-dataframe) (1.2.3)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\acer\anaconda3\lib\site-packages (from gspread>=3.0.0->gspread-dataframe) (1.30.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\acer\anaconda3\lib\site-packages (from gspread>=3.0.0->gspread-dataframe) (0.4.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.2.1)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (52.0.0.post20210125)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\acer\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (1.3.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\acer\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (1.19.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\acer\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\acer\anaconda3\lib\site-packages (from pandas>=0.24.0->gspread-dataframe) (2.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\acer\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.4.8)
# Requirement already satisfied: requests>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\acer\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.10)

# %%
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials

# %%
####Access the Google Sheet

#filename=ServiceAccountCredentials.from_json_keyfile_name('add_json_file_here.json', scope)
####scopes= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']###
gc = gspread.service_account('c:/Users/Acer/Downloads/Google_API_Credentials/mytest-project-311420-267223638303.json')
sh = gc.open_by_key('1Hrzto96H57_8xr_3v_bBZZHDAs9dU0vv0PB9sqAZ4mw')
worksheet = sh.get_worksheet(0)

# %%
### clear dataset instead of append data

### CLEAR SHEET CONTENT
# Method 1
# range_of_cells = worksheet.range('A1:J11727') #-> Select the range you want to clear
# for cell in range_of_cells:
#    cell.value = ''
#    worksheet.update_cells(range_of_cells)  ###

# Method 2    
#sh.values_clear("Worksheet!A1:J11727")
sh.values_clear("'Sheet1'!A1:Z")
# Out:
# {'spreadsheetId': '1Hrzto96H57_8xr_3v_bBZZHDAs9dU0vv0PB9sqAZ4mw',
#  'clearedRange': 'Sheet1!A1:Z11838'}

# %%
#### Append data to sheet
cov_prov_id = prov_id
set_with_dataframe(worksheet, cov_prov_id)
