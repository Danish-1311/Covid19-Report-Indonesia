# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 23632280 / 23632280

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 38471      IDN      Asia  Indonesia  2021-05-19    1753101.0     4871.0
# 38472      IDN      Asia  Indonesia  2021-05-20    1758898.0     5797.0
# 38473      IDN      Asia  Indonesia  2021-05-21    1764644.0     5746.0
# 38474      IDN      Asia  Indonesia  2021-05-22    1769940.0     5296.0
# 38475      IDN      Asia  Indonesia  2021-05-23    1775220.0     5280.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38471            3556.714       48669.0       192.0              150.286  ...
# 38472            3892.286       48887.0       218.0              167.286  ...
# 38473            4337.000       49073.0       186.0              178.571  ...
# 38474            4752.857       49205.0       132.0              176.857  ...
# 38475            5067.143       49328.0       123.0              176.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 38471       11188.744              5.7                342.864
# 38472       11188.744              5.7                342.864
# 38473       11188.744              5.7                342.864
# 38474       11188.744              5.7                342.864
# 38475       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 38471                 6.32             2.8          76.1
# 38472                 6.32             2.8          76.1
# 38473                 6.32             2.8          76.1
# 38474                 6.32             2.8          76.1
# 38475                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 38471                  64.204                        1.04            71.72
# 38472                  64.204                        1.04            71.72
# 38473                  64.204                        1.04            71.72
# 38474                  64.204                        1.04            71.72
# 38475                  64.204                        1.04            71.72
#
#        human_development_index
# 38471                    0.718
# 38472                    0.718
# 38473                    0.718
# 38474                    0.718
# 38475                    0.718
#
# [5 rows x 59 columns]

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 448 entries, 38028 to 38475
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               448 non-null    object
#  1   continent                              448 non-null    object
#  2   location                               448 non-null    object
#  3   date                                   448 non-null    object
#  4   total_cases                            448 non-null    float64
#  5   new_cases                              448 non-null    float64
#  6   new_cases_smoothed                     443 non-null    float64
#  7   total_deaths                           439 non-null    float64
#  8   new_deaths                             439 non-null    float64
#  9   new_deaths_smoothed                    443 non-null    float64
#  10  total_cases_per_million                448 non-null    float64
#  11  new_cases_per_million                  448 non-null    float64
#  12  new_cases_smoothed_per_million         443 non-null    float64
#  13  total_deaths_per_million               439 non-null    float64
#  14  new_deaths_per_million                 439 non-null    float64
#  15  new_deaths_smoothed_per_million        443 non-null    float64
#  16  reproduction_rate                      433 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              331 non-null    float64
#  26  total_tests                            367 non-null    float64
#  27  total_tests_per_thousand               367 non-null    float64
#  28  new_tests_per_thousand                 331 non-null    float64
#  29  new_tests_smoothed                     425 non-null    float64
#  30  new_tests_smoothed_per_thousand        425 non-null    float64
#  31  positive_rate                          424 non-null    float64
#  32  tests_per_case                         424 non-null    float64
#  33  tests_units                            432 non-null    object
#  34  total_vaccinations                     93 non-null     float64
#  35  people_vaccinated                      93 non-null     float64
#  36  people_fully_vaccinated                87 non-null     float64
#  37  new_vaccinations                       64 non-null     float64
#  38  new_vaccinations_smoothed              131 non-null    float64
#  39  total_vaccinations_per_hundred         93 non-null     float64
#  40  people_vaccinated_per_hundred          93 non-null     float64
#  41  people_fully_vaccinated_per_hundred    87 non-null     float64
#  42  new_vaccinations_smoothed_per_million  131 non-null    float64
#  43  stringency_index                       442 non-null    float64
#  44  population                             448 non-null    float64
#  45  population_density                     448 non-null    float64
#  46  median_age                             448 non-null    float64
#  47  aged_65_older                          448 non-null    float64
#  48  aged_70_older                          448 non-null    float64
#  49  gdp_per_capita                         448 non-null    float64
#  50  extreme_poverty                        448 non-null    float64
#  51  cardiovasc_death_rate                  448 non-null    float64
#  52  diabetes_prevalence                    448 non-null    float64
#  53  female_smokers                         448 non-null    float64
#  54  male_smokers                           448 non-null    float64
#  55  handwashing_facilities                 448 non-null    float64
#  56  hospital_beds_per_thousand             448 non-null    float64
#  57  life_expectancy                        448 non-null    float64
#  58  human_development_index                448 non-null    float64
# dtypes: float64(54), object(5)
# memory usage: 210.0+ KB
# None
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                               9
# new_deaths                                 9
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                   9
# new_deaths_per_million                     9
# new_deaths_smoothed_per_million            5
# reproduction_rate                         15
# icu_patients                             448
# icu_patients_per_million                 448
# hosp_patients                            448
# hosp_patients_per_million                448
# weekly_icu_admissions                    448
# weekly_icu_admissions_per_million        448
# weekly_hosp_admissions                   448
# weekly_hosp_admissions_per_million       448
# new_tests                                117
# total_tests                               81
# total_tests_per_thousand                  81
# new_tests_per_thousand                   117
# new_tests_smoothed                        23
# new_tests_smoothed_per_thousand           23
# positive_rate                             24
# tests_per_case                            24
# tests_units                               16
# total_vaccinations                       355
# people_vaccinated                        355
# people_fully_vaccinated                  361
# new_vaccinations                         384
# new_vaccinations_smoothed                317
# total_vaccinations_per_hundred           355
# people_vaccinated_per_hundred            355
# people_fully_vaccinated_per_hundred      361
# new_vaccinations_smoothed_per_million    317
# stringency_index                           6
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                            0
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                     0
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# dtype: int64

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 38028      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 38029      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 38030      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 38031      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 38032      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 38471      IDN      Asia  Indonesia  2021-05-19    1753101.0     4871.0
# 38472      IDN      Asia  Indonesia  2021-05-20    1758898.0     5797.0
# 38473      IDN      Asia  Indonesia  2021-05-21    1764644.0     5746.0
# 38474      IDN      Asia  Indonesia  2021-05-22    1769940.0     5296.0
# 38475      IDN      Asia  Indonesia  2021-05-23    1775220.0     5280.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38028               0.000           0.0         0.0                0.000  ...
# 38029               0.000           0.0         0.0                0.000  ...
# 38030               0.000           0.0         0.0                0.000  ...
# 38031               0.000           0.0         0.0                0.000  ...
# 38032               0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 38471            3556.714       48669.0       192.0              150.286  ...
# 38472            3892.286       48887.0       218.0              167.286  ...
# 38473            4337.000       49073.0       186.0              178.571  ...
# 38474            4752.857       49205.0       132.0              176.857  ...
# 38475            5067.143       49328.0       123.0              176.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 38028       11188.744              5.7                342.864
# 38029       11188.744              5.7                342.864
# 38030       11188.744              5.7                342.864
# 38031       11188.744              5.7                342.864
# 38032       11188.744              5.7                342.864
# ...               ...              ...                    ...
# 38471       11188.744              5.7                342.864
# 38472       11188.744              5.7                342.864
# 38473       11188.744              5.7                342.864
# 38474       11188.744              5.7                342.864
# 38475       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 38028                 6.32             2.8          76.1
# 38029                 6.32             2.8          76.1
# 38030                 6.32             2.8          76.1
# 38031                 6.32             2.8          76.1
# 38032                 6.32             2.8          76.1
# ...                    ...             ...           ...
# 38471                 6.32             2.8          76.1
# 38472                 6.32             2.8          76.1
# 38473                 6.32             2.8          76.1
# 38474                 6.32             2.8          76.1
# 38475                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 38028                  64.204                        1.04            71.72
# 38029                  64.204                        1.04            71.72
# 38030                  64.204                        1.04            71.72
# 38031                  64.204                        1.04            71.72
# 38032                  64.204                        1.04            71.72
# ...                       ...                         ...              ...
# 38471                  64.204                        1.04            71.72
# 38472                  64.204                        1.04            71.72
# 38473                  64.204                        1.04            71.72
# 38474                  64.204                        1.04            71.72
# 38475                  64.204                        1.04            71.72
#
#        human_development_index
# 38028                    0.718
# 38029                    0.718
# 38030                    0.718
# 38031                    0.718
# 38032                    0.718
# ...                        ...
# 38471                    0.718
# 38472                    0.718
# 38473                    0.718
# 38474                    0.718
# 38475                    0.718
#
# [448 rows x 59 columns]

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
