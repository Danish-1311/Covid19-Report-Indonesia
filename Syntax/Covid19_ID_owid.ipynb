# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 24235943 / 24235943

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 39336      IDN      Asia  Indonesia  2021-05-28    1803361.0     5862.0
# 39337      IDN      Asia  Indonesia  2021-05-29    1809926.0     6565.0
# 39338      IDN      Asia  Indonesia  2021-05-30    1816041.0     6115.0
# 39339      IDN      Asia  Indonesia  2021-05-31    1821703.0     5662.0
# 39340      IDN      Asia  Indonesia  2021-06-01    1826527.0     4824.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 39336            5531.000       50100.0       193.0              146.714  ...
# 39337            5712.286       50262.0       162.0              151.000  ...
# 39338            5831.571       50404.0       142.0              153.714  ...
# 39339            5796.571       50578.0       174.0              160.429  ...
# 39340            5762.857       50723.0       145.0              156.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 39336       11188.744              5.7                342.864
# 39337       11188.744              5.7                342.864
# 39338       11188.744              5.7                342.864
# 39339       11188.744              5.7                342.864
# 39340       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 39336                 6.32             2.8          76.1
# 39337                 6.32             2.8          76.1
# 39338                 6.32             2.8          76.1
# 39339                 6.32             2.8          76.1
# 39340                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 39336                  64.204                        1.04            71.72
# 39337                  64.204                        1.04            71.72
# 39338                  64.204                        1.04            71.72
# 39339                  64.204                        1.04            71.72
# 39340                  64.204                        1.04            71.72
#
#        human_development_index
# 39336                    0.718
# 39337                    0.718
# 39338                    0.718
# 39339                    0.718
# 39340                    0.718
#
# [5 rows x 59 columns]

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 38884 to 39340
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               457 non-null    object
#  1   continent                              457 non-null    object
#  2   location                               457 non-null    object
#  3   date                                   457 non-null    object
#  4   total_cases                            457 non-null    float64
#  5   new_cases                              457 non-null    float64
#  6   new_cases_smoothed                     452 non-null    float64
#  7   total_deaths                           448 non-null    float64
#  8   new_deaths                             448 non-null    float64
#  9   new_deaths_smoothed                    452 non-null    float64
#  10  total_cases_per_million                457 non-null    float64
#  11  new_cases_per_million                  457 non-null    float64
#  12  new_cases_smoothed_per_million         452 non-null    float64
#  13  total_deaths_per_million               448 non-null    float64
#  14  new_deaths_per_million                 448 non-null    float64
#  15  new_deaths_smoothed_per_million        452 non-null    float64
#  16  reproduction_rate                      441 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              339 non-null    float64
#  26  total_tests                            376 non-null    float64
#  27  total_tests_per_thousand               376 non-null    float64
#  28  new_tests_per_thousand                 339 non-null    float64
#  29  new_tests_smoothed                     435 non-null    float64
#  30  new_tests_smoothed_per_thousand        435 non-null    float64
#  31  positive_rate                          435 non-null    float64
#  32  tests_per_case                         435 non-null    float64
#  33  tests_units                            442 non-null    object
#  34  total_vaccinations                     98 non-null     float64
#  35  people_vaccinated                      98 non-null     float64
#  36  people_fully_vaccinated                92 non-null     float64
#  37  new_vaccinations                       68 non-null     float64
#  38  new_vaccinations_smoothed              140 non-null    float64
#  39  total_vaccinations_per_hundred         98 non-null     float64
#  40  people_vaccinated_per_hundred          98 non-null     float64
#  41  people_fully_vaccinated_per_hundred    92 non-null     float64
#  42  new_vaccinations_smoothed_per_million  140 non-null    float64
#  43  stringency_index                       456 non-null    float64
#  44  population                             457 non-null    float64
#  45  population_density                     457 non-null    float64
#  46  median_age                             457 non-null    float64
#  47  aged_65_older                          457 non-null    float64
#  48  aged_70_older                          457 non-null    float64
#  49  gdp_per_capita                         457 non-null    float64
#  50  extreme_poverty                        457 non-null    float64
#  51  cardiovasc_death_rate                  457 non-null    float64
#  52  diabetes_prevalence                    457 non-null    float64
#  53  female_smokers                         457 non-null    float64
#  54  male_smokers                           457 non-null    float64
#  55  handwashing_facilities                 457 non-null    float64
#  56  hospital_beds_per_thousand             457 non-null    float64
#  57  life_expectancy                        457 non-null    float64
#  58  human_development_index                457 non-null    float64
# dtypes: float64(54), object(5)
# memory usage: 214.2+ KB
# None
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                               9
# new_deaths                                 9
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                   9
# new_deaths_per_million                     9
# new_deaths_smoothed_per_million            5
# reproduction_rate                         16
# icu_patients                             457
# icu_patients_per_million                 457
# hosp_patients                            457
# hosp_patients_per_million                457
# weekly_icu_admissions                    457
# weekly_icu_admissions_per_million        457
# weekly_hosp_admissions                   457
# weekly_hosp_admissions_per_million       457
# new_tests                                118
# total_tests                               81
# total_tests_per_thousand                  81
# new_tests_per_thousand                   118
# new_tests_smoothed                        22
# new_tests_smoothed_per_thousand           22
# positive_rate                             22
# tests_per_case                            22
# tests_units                               15
# total_vaccinations                       359
# people_vaccinated                        359
# people_fully_vaccinated                  365
# new_vaccinations                         389
# new_vaccinations_smoothed                317
# total_vaccinations_per_hundred           359
# people_vaccinated_per_hundred            359
# people_fully_vaccinated_per_hundred      365
# new_vaccinations_smoothed_per_million    317
# stringency_index                           1
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                            0
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                     0
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# dtype: int64

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 38884      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 38885      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 38886      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 38887      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 38888      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 39336      IDN      Asia  Indonesia  2021-05-28    1803361.0     5862.0
# 39337      IDN      Asia  Indonesia  2021-05-29    1809926.0     6565.0
# 39338      IDN      Asia  Indonesia  2021-05-30    1816041.0     6115.0
# 39339      IDN      Asia  Indonesia  2021-05-31    1821703.0     5662.0
# 39340      IDN      Asia  Indonesia  2021-06-01    1826527.0     4824.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38884               0.000           0.0         0.0                0.000  ...
# 38885               0.000           0.0         0.0                0.000  ...
# 38886               0.000           0.0         0.0                0.000  ...
# 38887               0.000           0.0         0.0                0.000  ...
# 38888               0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 39336            5531.000       50100.0       193.0              146.714  ...
# 39337            5712.286       50262.0       162.0              151.000  ...
# 39338            5831.571       50404.0       142.0              153.714  ...
# 39339            5796.571       50578.0       174.0              160.429  ...
# 39340            5762.857       50723.0       145.0              156.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 38884       11188.744              5.7                342.864
# 38885       11188.744              5.7                342.864
# 38886       11188.744              5.7                342.864
# 38887       11188.744              5.7                342.864
# 38888       11188.744              5.7                342.864
# ...               ...              ...                    ...
# 39336       11188.744              5.7                342.864
# 39337       11188.744              5.7                342.864
# 39338       11188.744              5.7                342.864
# 39339       11188.744              5.7                342.864
# 39340       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 38884                 6.32             2.8          76.1
# 38885                 6.32             2.8          76.1
# 38886                 6.32             2.8          76.1
# 38887                 6.32             2.8          76.1
# 38888                 6.32             2.8          76.1
# ...                    ...             ...           ...
# 39336                 6.32             2.8          76.1
# 39337                 6.32             2.8          76.1
# 39338                 6.32             2.8          76.1
# 39339                 6.32             2.8          76.1
# 39340                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 38884                  64.204                        1.04            71.72
# 38885                  64.204                        1.04            71.72
# 38886                  64.204                        1.04            71.72
# 38887                  64.204                        1.04            71.72
# 38888                  64.204                        1.04            71.72
# ...                       ...                         ...              ...
# 39336                  64.204                        1.04            71.72
# 39337                  64.204                        1.04            71.72
# 39338                  64.204                        1.04            71.72
# 39339                  64.204                        1.04            71.72
# 39340                  64.204                        1.04            71.72
#
#        human_development_index
# 38884                    0.718
# 38885                    0.718
# 38886                    0.718
# 38887                    0.718
# 38888                    0.718
# ...                        ...
# 39336                    0.718
# 39337                    0.718
# 39338                    0.718
# 39339                    0.718
# 39340                    0.718
#
# [457 rows x 59 columns]

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
