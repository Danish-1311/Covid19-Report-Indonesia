# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 23299260 / 23299260

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 38009      IDN      Asia  Indonesia  2021-05-14    1734285.0     2633.0
# 38010      IDN      Asia  Indonesia  2021-05-15    1736670.0     2385.0
# 38011      IDN      Asia  Indonesia  2021-05-16    1739750.0     3080.0
# 38012      IDN      Asia  Indonesia  2021-05-17    1744045.0     4295.0
# 38013      IDN      Asia  Indonesia  2021-05-18    1748230.0     4185.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38009            4379.000       47823.0       107.0              165.714  ...
# 38010            3844.000       47967.0       144.0              160.714  ...
# 38011            3723.714       48093.0       126.0              154.429  ...
# 38012            3638.571       48305.0       212.0              155.286  ...
# 38013            3519.143       48477.0       172.0              144.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 38009       11188.744              5.7                342.864
# 38010       11188.744              5.7                342.864
# 38011       11188.744              5.7                342.864
# 38012       11188.744              5.7                342.864
# 38013       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 38009                 6.32             2.8          76.1
# 38010                 6.32             2.8          76.1
# 38011                 6.32             2.8          76.1
# 38012                 6.32             2.8          76.1
# 38013                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 38009                  64.204                        1.04            71.72
# 38010                  64.204                        1.04            71.72
# 38011                  64.204                        1.04            71.72
# 38012                  64.204                        1.04            71.72
# 38013                  64.204                        1.04            71.72
#
#        human_development_index
# 38009                    0.718
# 38010                    0.718
# 38011                    0.718
# 38012                    0.718
# 38013                    0.718
#
# [5 rows x 59 columns]

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 37571 to 38013
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               443 non-null    object
#  1   continent                              443 non-null    object
#  2   location                               443 non-null    object
#  3   date                                   443 non-null    object
#  4   total_cases                            443 non-null    float64
#  5   new_cases                              443 non-null    float64
#  6   new_cases_smoothed                     438 non-null    float64
#  7   total_deaths                           434 non-null    float64
#  8   new_deaths                             434 non-null    float64
#  9   new_deaths_smoothed                    438 non-null    float64
#  10  total_cases_per_million                443 non-null    float64
#  11  new_cases_per_million                  443 non-null    float64
#  12  new_cases_smoothed_per_million         438 non-null    float64
#  13  total_deaths_per_million               434 non-null    float64
#  14  new_deaths_per_million                 434 non-null    float64
#  15  new_deaths_smoothed_per_million        438 non-null    float64
#  16  reproduction_rate                      427 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              326 non-null    float64
#  26  total_tests                            362 non-null    float64
#  27  total_tests_per_thousand               362 non-null    float64
#  28  new_tests_per_thousand                 326 non-null    float64
#  29  new_tests_smoothed                     420 non-null    float64
#  30  new_tests_smoothed_per_thousand        420 non-null    float64
#  31  positive_rate                          420 non-null    float64
#  32  tests_per_case                         420 non-null    float64
#  33  tests_units                            427 non-null    object
#  34  total_vaccinations                     90 non-null     float64
#  35  people_vaccinated                      90 non-null     float64
#  36  people_fully_vaccinated                84 non-null     float64
#  37  new_vaccinations                       63 non-null     float64
#  38  new_vaccinations_smoothed              126 non-null    float64
#  39  total_vaccinations_per_hundred         90 non-null     float64
#  40  people_vaccinated_per_hundred          90 non-null     float64
#  41  people_fully_vaccinated_per_hundred    84 non-null     float64
#  42  new_vaccinations_smoothed_per_million  126 non-null    float64
#  43  stringency_index                       436 non-null    float64
#  44  population                             443 non-null    float64
#  45  population_density                     443 non-null    float64
#  46  median_age                             443 non-null    float64
#  47  aged_65_older                          443 non-null    float64
#  48  aged_70_older                          443 non-null    float64
#  49  gdp_per_capita                         443 non-null    float64
#  50  extreme_poverty                        443 non-null    float64
#  51  cardiovasc_death_rate                  443 non-null    float64
#  52  diabetes_prevalence                    443 non-null    float64
#  53  female_smokers                         443 non-null    float64
#  54  male_smokers                           443 non-null    float64
#  55  handwashing_facilities                 443 non-null    float64
#  56  hospital_beds_per_thousand             443 non-null    float64
#  57  life_expectancy                        443 non-null    float64
#  58  human_development_index                443 non-null    float64
# dtypes: float64(54), object(5)
# memory usage: 207.7+ KB
# None
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                               9
# new_deaths                                 9
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                   9
# new_deaths_per_million                     9
# new_deaths_smoothed_per_million            5
# reproduction_rate                         16
# icu_patients                             443
# icu_patients_per_million                 443
# hosp_patients                            443
# hosp_patients_per_million                443
# weekly_icu_admissions                    443
# weekly_icu_admissions_per_million        443
# weekly_hosp_admissions                   443
# weekly_hosp_admissions_per_million       443
# new_tests                                117
# total_tests                               81
# total_tests_per_thousand                  81
# new_tests_per_thousand                   117
# new_tests_smoothed                        23
# new_tests_smoothed_per_thousand           23
# positive_rate                             23
# tests_per_case                            23
# tests_units                               16
# total_vaccinations                       353
# people_vaccinated                        353
# people_fully_vaccinated                  359
# new_vaccinations                         380
# new_vaccinations_smoothed                317
# total_vaccinations_per_hundred           353
# people_vaccinated_per_hundred            353
# people_fully_vaccinated_per_hundred      359
# new_vaccinations_smoothed_per_million    317
# stringency_index                           7
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                            0
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                     0
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# dtype: int64

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 37571      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 37572      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 37573      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 37574      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 37575      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 38009      IDN      Asia  Indonesia  2021-05-14    1734285.0     2633.0
# 38010      IDN      Asia  Indonesia  2021-05-15    1736670.0     2385.0
# 38011      IDN      Asia  Indonesia  2021-05-16    1739750.0     3080.0
# 38012      IDN      Asia  Indonesia  2021-05-17    1744045.0     4295.0
# 38013      IDN      Asia  Indonesia  2021-05-18    1748230.0     4185.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 37571               0.000           0.0         0.0                0.000  ...
# 37572               0.000           0.0         0.0                0.000  ...
# 37573               0.000           0.0         0.0                0.000  ...
# 37574               0.000           0.0         0.0                0.000  ...
# 37575               0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 38009            4379.000       47823.0       107.0              165.714  ...
# 38010            3844.000       47967.0       144.0              160.714  ...
# 38011            3723.714       48093.0       126.0              154.429  ...
# 38012            3638.571       48305.0       212.0              155.286  ...
# 38013            3519.143       48477.0       172.0              144.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 37571       11188.744              5.7                342.864
# 37572       11188.744              5.7                342.864
# 37573       11188.744              5.7                342.864
# 37574       11188.744              5.7                342.864
# 37575       11188.744              5.7                342.864
# ...               ...              ...                    ...
# 38009       11188.744              5.7                342.864
# 38010       11188.744              5.7                342.864
# 38011       11188.744              5.7                342.864
# 38012       11188.744              5.7                342.864
# 38013       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 37571                 6.32             2.8          76.1
# 37572                 6.32             2.8          76.1
# 37573                 6.32             2.8          76.1
# 37574                 6.32             2.8          76.1
# 37575                 6.32             2.8          76.1
# ...                    ...             ...           ...
# 38009                 6.32             2.8          76.1
# 38010                 6.32             2.8          76.1
# 38011                 6.32             2.8          76.1
# 38012                 6.32             2.8          76.1
# 38013                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 37571                  64.204                        1.04            71.72
# 37572                  64.204                        1.04            71.72
# 37573                  64.204                        1.04            71.72
# 37574                  64.204                        1.04            71.72
# 37575                  64.204                        1.04            71.72
# ...                       ...                         ...              ...
# 38009                  64.204                        1.04            71.72
# 38010                  64.204                        1.04            71.72
# 38011                  64.204                        1.04            71.72
# 38012                  64.204                        1.04            71.72
# 38013                  64.204                        1.04            71.72
#
#        human_development_index
# 37571                    0.718
# 37572                    0.718
# 37573                    0.718
# 37574                    0.718
# 37575                    0.718
# ...                        ...
# 38009                    0.718
# 38010                    0.718
# 38011                    0.718
# 38012                    0.718
# 38013                    0.718
#
# [443 rows x 59 columns]

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
