# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 25348640 / 25348640

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 40838      IDN      Asia  Indonesia  2021-06-13    1911358.0     9868.0
# 40839      IDN      Asia  Indonesia  2021-06-14    1919547.0     8189.0
# 40840      IDN      Asia  Indonesia  2021-06-15    1927708.0     8161.0
# 40841      IDN      Asia  Indonesia  2021-06-16    1937652.0     9944.0
# 40842      IDN      Asia  Indonesia  2021-06-17    1950276.0    12624.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 40838            7902.857       52879.0       149.0              181.000  ...
# 40839            8073.714       53116.0       237.0              187.571  ...
# 40840            8340.429       53280.0       164.0              184.000  ...
# 40841            8657.429       53476.0       196.0              187.714  ...
# 40842            9190.571       53753.0       277.0              197.143  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 40838              5.7                342.864                 6.32
# 40839              5.7                342.864                 6.32
# 40840              5.7                342.864                 6.32
# 40841              5.7                342.864                 6.32
# 40842              5.7                342.864                 6.32
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 40838             2.8          76.1                  64.204
# 40839             2.8          76.1                  64.204
# 40840             2.8          76.1                  64.204
# 40841             2.8          76.1                  64.204
# 40842             2.8          76.1                  64.204
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 40838                        1.04            71.72                    0.718
# 40839                        1.04            71.72                    0.718
# 40840                        1.04            71.72                    0.718
# 40841                        1.04            71.72                    0.718
# 40842                        1.04            71.72                    0.718
#
#        excess_mortality
# 40838               NaN
# 40839               NaN
# 40840               NaN
# 40841               NaN
# 40842               NaN
#
# [5 rows x 60 columns]

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 473 entries, 40370 to 40842
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               473 non-null    object
#  1   continent                              473 non-null    object
#  2   location                               473 non-null    object
#  3   date                                   473 non-null    object
#  4   total_cases                            473 non-null    float64
#  5   new_cases                              473 non-null    float64
#  6   new_cases_smoothed                     468 non-null    float64
#  7   total_deaths                           464 non-null    float64
#  8   new_deaths                             464 non-null    float64
#  9   new_deaths_smoothed                    468 non-null    float64
#  10  total_cases_per_million                473 non-null    float64
#  11  new_cases_per_million                  473 non-null    float64
#  12  new_cases_smoothed_per_million         468 non-null    float64
#  13  total_deaths_per_million               464 non-null    float64
#  14  new_deaths_per_million                 464 non-null    float64
#  15  new_deaths_smoothed_per_million        468 non-null    float64
#  16  reproduction_rate                      457 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              352 non-null    float64
#  26  total_tests                            390 non-null    float64
#  27  total_tests_per_thousand               390 non-null    float64
#  28  new_tests_per_thousand                 352 non-null    float64
#  29  new_tests_smoothed                     450 non-null    float64
#  30  new_tests_smoothed_per_thousand        450 non-null    float64
#  31  positive_rate                          450 non-null    float64
#  32  tests_per_case                         450 non-null    float64
#  33  tests_units                            457 non-null    object
#  34  total_vaccinations                     113 non-null    float64
#  35  people_vaccinated                      113 non-null    float64
#  36  people_fully_vaccinated                107 non-null    float64
#  37  new_vaccinations                       83 non-null     float64
#  38  new_vaccinations_smoothed              155 non-null    float64
#  39  total_vaccinations_per_hundred         113 non-null    float64
#  40  people_vaccinated_per_hundred          113 non-null    float64
#  41  people_fully_vaccinated_per_hundred    107 non-null    float64
#  42  new_vaccinations_smoothed_per_million  155 non-null    float64
#  43  stringency_index                       470 non-null    float64
#  44  population                             473 non-null    float64
#  45  population_density                     473 non-null    float64
#  46  median_age                             473 non-null    float64
#  47  aged_65_older                          473 non-null    float64
#  48  aged_70_older                          473 non-null    float64
#  49  gdp_per_capita                         473 non-null    float64
#  50  extreme_poverty                        473 non-null    float64
#  51  cardiovasc_death_rate                  473 non-null    float64
#  52  diabetes_prevalence                    473 non-null    float64
#  53  female_smokers                         473 non-null    float64
#  54  male_smokers                           473 non-null    float64
#  55  handwashing_facilities                 473 non-null    float64
#  56  hospital_beds_per_thousand             473 non-null    float64
#  57  life_expectancy                        473 non-null    float64
#  58  human_development_index                473 non-null    float64
#  59  excess_mortality                       0 non-null      float64
# dtypes: float64(55), object(5)
# memory usage: 225.4+ KB
# None
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                               9
# new_deaths                                 9
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                   9
# new_deaths_per_million                     9
# new_deaths_smoothed_per_million            5
# reproduction_rate                         16
# icu_patients                             473
# icu_patients_per_million                 473
# hosp_patients                            473
# hosp_patients_per_million                473
# weekly_icu_admissions                    473
# weekly_icu_admissions_per_million        473
# weekly_hosp_admissions                   473
# weekly_hosp_admissions_per_million       473
# new_tests                                121
# total_tests                               83
# total_tests_per_thousand                  83
# new_tests_per_thousand                   121
# new_tests_smoothed                        23
# new_tests_smoothed_per_thousand           23
# positive_rate                             23
# tests_per_case                            23
# tests_units                               16
# total_vaccinations                       360
# people_vaccinated                        360
# people_fully_vaccinated                  366
# new_vaccinations                         390
# new_vaccinations_smoothed                318
# total_vaccinations_per_hundred           360
# people_vaccinated_per_hundred            360
# people_fully_vaccinated_per_hundred      366
# new_vaccinations_smoothed_per_million    318
# stringency_index                           3
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                            0
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                     0
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# excess_mortality                         473
# dtype: int64

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 40370      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 40371      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 40372      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 40373      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 40374      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 40838      IDN      Asia  Indonesia  2021-06-13    1911358.0     9868.0
# 40839      IDN      Asia  Indonesia  2021-06-14    1919547.0     8189.0
# 40840      IDN      Asia  Indonesia  2021-06-15    1927708.0     8161.0
# 40841      IDN      Asia  Indonesia  2021-06-16    1937652.0     9944.0
# 40842      IDN      Asia  Indonesia  2021-06-17    1950276.0    12624.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 40370               0.000           0.0         0.0                0.000  ...
# 40371               0.000           0.0         0.0                0.000  ...
# 40372               0.000           0.0         0.0                0.000  ...
# 40373               0.000           0.0         0.0                0.000  ...
# 40374               0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 40838            7902.857       52879.0       149.0              181.000  ...
# 40839            8073.714       53116.0       237.0              187.571  ...
# 40840            8340.429       53280.0       164.0              184.000  ...
# 40841            8657.429       53476.0       196.0              187.714  ...
# 40842            9190.571       53753.0       277.0              197.143  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 40370              5.7                342.864                 6.32
# 40371              5.7                342.864                 6.32
# 40372              5.7                342.864                 6.32
# 40373              5.7                342.864                 6.32
# 40374              5.7                342.864                 6.32
# ...                ...                    ...                  ...
# 40838              5.7                342.864                 6.32
# 40839              5.7                342.864                 6.32
# 40840              5.7                342.864                 6.32
# 40841              5.7                342.864                 6.32
# 40842              5.7                342.864                 6.32
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 40370             2.8          76.1                  64.204
# 40371             2.8          76.1                  64.204
# 40372             2.8          76.1                  64.204
# 40373             2.8          76.1                  64.204
# 40374             2.8          76.1                  64.204
# ...               ...           ...                     ...
# 40838             2.8          76.1                  64.204
# 40839             2.8          76.1                  64.204
# 40840             2.8          76.1                  64.204
# 40841             2.8          76.1                  64.204
# 40842             2.8          76.1                  64.204
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 40370                        1.04            71.72                    0.718
# 40371                        1.04            71.72                    0.718
# 40372                        1.04            71.72                    0.718
# 40373                        1.04            71.72                    0.718
# 40374                        1.04            71.72                    0.718
# ...                           ...              ...                      ...
# 40838                        1.04            71.72                    0.718
# 40839                        1.04            71.72                    0.718
# 40840                        1.04            71.72                    0.718
# 40841                        1.04            71.72                    0.718
# 40842                        1.04            71.72                    0.718
#
#        excess_mortality
# 40370               0.0
# 40371               0.0
# 40372               0.0
# 40373               0.0
# 40374               0.0
# ...                 ...
# 40838               0.0
# 40839               0.0
# 40840               0.0
# 40841               0.0
# 40842               0.0
#
# [473 rows x 60 columns]

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
