# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 23459433 / 23459433

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 38200      IDN      Asia  Indonesia  2021-05-16    1739750.0     3080.0
# 38201      IDN      Asia  Indonesia  2021-05-17    1744045.0     4295.0
# 38202      IDN      Asia  Indonesia  2021-05-18    1748230.0     4185.0
# 38203      IDN      Asia  Indonesia  2021-05-19    1753101.0     4871.0
# 38204      IDN      Asia  Indonesia  2021-05-20    1758898.0     5797.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38200            3723.714       48093.0       126.0              154.429  ...
# 38201            3638.571       48305.0       212.0              155.286  ...
# 38202            3519.143       48477.0       172.0              144.571  ...
# 38203            3556.714       48669.0       192.0              150.286  ...
# 38204            3892.286       48887.0       218.0              167.286  ...
#
# ...

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445 entries, 37760 to 38204
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               445 non-null    object
#  1   continent                              445 non-null    object
#  2   location                               445 non-null    object
#  3   date                                   445 non-null    object
#  4   total_cases                            445 non-null    float64
#  5   new_cases                              445 non-null    float64
#  6   new_cases_smoothed                     440 non-null    float64
#  7   total_deaths                           436 non-null    float64
#  8   new_deaths                             436 non-null    float64
#  9   new_deaths_smoothed                    440 non-null    float64
# ...

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 37760      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 37761      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 37762      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 37763      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 37764      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 38200      IDN      Asia  Indonesia  2021-05-16    1739750.0     3080.0
# 38201      IDN      Asia  Indonesia  2021-05-17    1744045.0     4295.0
# 38202      IDN      Asia  Indonesia  2021-05-18    1748230.0     4185.0
# 38203      IDN      Asia  Indonesia  2021-05-19    1753101.0     4871.0
# 38204      IDN      Asia  Indonesia  2021-05-20    1758898.0     5797.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
