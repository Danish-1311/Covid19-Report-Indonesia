# %%
import numpy as np
import pandas as pd 
import wget
import os

url_owid = ['https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv']

path_url = r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid'

for url in url_owid:
    filename= path_url + '/' + os.path.basename(url)
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=path_url)
# Out:
# 100% [........................................................................] 28240930 / 28240930

# %%
cov19_data_owid = pd.read_csv(r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid\owid-covid-data.csv')
cov19_data_owid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
cov19_id_owid = cov19_data_owid[cov19_data_owid['location'] == 'Indonesia']
cov19_id_owid.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 45105      IDN      Asia  Indonesia  2021-07-28    3287727.0    47791.0
# 45106      IDN      Asia  Indonesia  2021-07-29    3331206.0    43479.0
# 45107      IDN      Asia  Indonesia  2021-07-30    3372374.0    41168.0
# 45108      IDN      Asia  Indonesia  2021-07-31    3409658.0    37284.0
# 45109      IDN      Asia  Indonesia  2021-08-01    3440396.0    30738.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 45105           43413.857       88659.0      1824.0             1582.286  ...
# 45106           42552.429       90552.0      1893.0             1645.714  ...
# 45107           41423.429       92311.0      1759.0             1673.286  ...
# 45108           40261.714       94119.0      1808.0             1729.429  ...
# 45109           39127.286       95723.0      1604.0             1777.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 45105              5.7                342.864                 6.32
# 45106              5.7                342.864                 6.32
# 45107              5.7                342.864                 6.32
# 45108              5.7                342.864                 6.32
# 45109              5.7                342.864                 6.32
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 45105             2.8          76.1                  64.204
# 45106             2.8          76.1                  64.204
# 45107             2.8          76.1                  64.204
# 45108             2.8          76.1                  64.204
# 45109             2.8          76.1                  64.204
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 45105                        1.04            71.72                    0.718
# 45106                        1.04            71.72                    0.718
# 45107                        1.04            71.72                    0.718
# 45108                        1.04            71.72                    0.718
# 45109                        1.04            71.72                    0.718
#
#        excess_mortality
# 45105               NaN
# 45106               NaN
# 45107               NaN
# 45108               NaN
# 45109               NaN
#
# [5 rows x 60 columns]

# %%
print(cov19_id_owid.info())
print(cov19_id_owid.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 518 entries, 44592 to 45109
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               518 non-null    object
#  1   continent                              518 non-null    object
#  2   location                               518 non-null    object
#  3   date                                   518 non-null    object
#  4   total_cases                            518 non-null    float64
#  5   new_cases                              518 non-null    float64
#  6   new_cases_smoothed                     513 non-null    float64
#  7   total_deaths                           509 non-null    float64
#  8   new_deaths                             509 non-null    float64
#  9   new_deaths_smoothed                    513 non-null    float64
#  10  total_cases_per_million                518 non-null    float64
#  11  new_cases_per_million                  518 non-null    float64
#  12  new_cases_smoothed_per_million         513 non-null    float64
#  13  total_deaths_per_million               509 non-null    float64
#  14  new_deaths_per_million                 509 non-null    float64
#  15  new_deaths_smoothed_per_million        513 non-null    float64
#  16  reproduction_rate                      502 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              384 non-null    float64
#  26  total_tests                            426 non-null    float64
#  27  total_tests_per_thousand               426 non-null    float64
#  28  new_tests_per_thousand                 384 non-null    float64
#  29  new_tests_smoothed                     493 non-null    float64
#  30  new_tests_smoothed_per_thousand        493 non-null    float64
#  31  positive_rate                          493 non-null    float64
#  32  tests_per_case                         493 non-null    float64
#  33  tests_units                            500 non-null    object
#  34  total_vaccinations                     159 non-null    float64
#  35  people_vaccinated                      159 non-null    float64
#  36  people_fully_vaccinated                153 non-null    float64
#  37  new_vaccinations                       129 non-null    float64
#  38  new_vaccinations_smoothed              201 non-null    float64
#  39  total_vaccinations_per_hundred         159 non-null    float64
#  40  people_vaccinated_per_hundred          159 non-null    float64
#  41  people_fully_vaccinated_per_hundred    153 non-null    float64
#  42  new_vaccinations_smoothed_per_million  201 non-null    float64
#  43  stringency_index                       513 non-null    float64
#  44  population                             518 non-null    float64
#  45  population_density                     518 non-null    float64
#  46  median_age                             518 non-null    float64
#  47  aged_65_older                          518 non-null    float64
#  48  aged_70_older                          518 non-null    float64
#  49  gdp_per_capita                         518 non-null    float64
#  50  extreme_poverty                        518 non-null    float64
#  51  cardiovasc_death_rate                  518 non-null    float64
#  52  diabetes_prevalence                    518 non-null    float64
#  53  female_smokers                         518 non-null    float64
#  54  male_smokers                           518 non-null    float64
#  55  handwashing_facilities                 518 non-null    float64
#  56  hospital_beds_per_thousand             518 non-null    float64
#  57  life_expectancy                        518 non-null    float64
#  58  human_development_index                518 non-null    float64
#  59  excess_mortality                       0 non-null      float64
# dtypes: float64(55), object(5)
# memory usage: 246.9+ KB
# None
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                               9
# new_deaths                                 9
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                   9
# new_deaths_per_million                     9
# new_deaths_smoothed_per_million            5
# reproduction_rate                         16
# icu_patients                             518
# icu_patients_per_million                 518
# hosp_patients                            518
# hosp_patients_per_million                518
# weekly_icu_admissions                    518
# weekly_icu_admissions_per_million        518
# weekly_hosp_admissions                   518
# weekly_hosp_admissions_per_million       518
# new_tests                                134
# total_tests                               92
# total_tests_per_thousand                  92
# new_tests_per_thousand                   134
# new_tests_smoothed                        25
# new_tests_smoothed_per_thousand           25
# positive_rate                             25
# tests_per_case                            25
# tests_units                               18
# total_vaccinations                       359
# people_vaccinated                        359
# people_fully_vaccinated                  365
# new_vaccinations                         389
# new_vaccinations_smoothed                317
# total_vaccinations_per_hundred           359
# people_vaccinated_per_hundred            359
# people_fully_vaccinated_per_hundred      365
# new_vaccinations_smoothed_per_million    317
# stringency_index                           5
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                            0
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                     0
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# excess_mortality                         518
# dtype: int64

# %%
# Handle missing value:
## first using ffill method
cov19_id_owid = cov19_id_owid.fillna(method='ffill')

# %%
## second, replace null values with 0
cov19_id_owid = cov19_id_owid.fillna(0)

# %%
cov19_id_owid
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 44592      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 44593      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 44594      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 44595      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 44596      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
# ...        ...       ...        ...         ...          ...        ...
# 45105      IDN      Asia  Indonesia  2021-07-28    3287727.0    47791.0
# 45106      IDN      Asia  Indonesia  2021-07-29    3331206.0    43479.0
# 45107      IDN      Asia  Indonesia  2021-07-30    3372374.0    41168.0
# 45108      IDN      Asia  Indonesia  2021-07-31    3409658.0    37284.0
# 45109      IDN      Asia  Indonesia  2021-08-01    3440396.0    30738.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 44592               0.000           0.0         0.0                0.000  ...
# 44593               0.000           0.0         0.0                0.000  ...
# 44594               0.000           0.0         0.0                0.000  ...
# 44595               0.000           0.0         0.0                0.000  ...
# 44596               0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 45105           43413.857       88659.0      1824.0             1582.286  ...
# 45106           42552.429       90552.0      1893.0             1645.714  ...
# 45107           41423.429       92311.0      1759.0             1673.286  ...
# 45108           40261.714       94119.0      1808.0             1729.429  ...
# 45109           39127.286       95723.0      1604.0             1777.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 44592              5.7                342.864                 6.32
# 44593              5.7                342.864                 6.32
# 44594              5.7                342.864                 6.32
# 44595              5.7                342.864                 6.32
# 44596              5.7                342.864                 6.32
# ...                ...                    ...                  ...
# 45105              5.7                342.864                 6.32
# 45106              5.7                342.864                 6.32
# 45107              5.7                342.864                 6.32
# 45108              5.7                342.864                 6.32
# 45109              5.7                342.864                 6.32
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 44592             2.8          76.1                  64.204
# 44593             2.8          76.1                  64.204
# 44594             2.8          76.1                  64.204
# 44595             2.8          76.1                  64.204
# 44596             2.8          76.1                  64.204
# ...               ...           ...                     ...
# 45105             2.8          76.1                  64.204
# 45106             2.8          76.1                  64.204
# 45107             2.8          76.1                  64.204
# 45108             2.8          76.1                  64.204
# 45109             2.8          76.1                  64.204
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 44592                        1.04            71.72                    0.718
# 44593                        1.04            71.72                    0.718
# 44594                        1.04            71.72                    0.718
# 44595                        1.04            71.72                    0.718
# 44596                        1.04            71.72                    0.718
# ...                           ...              ...                      ...
# 45105                        1.04            71.72                    0.718
# 45106                        1.04            71.72                    0.718
# 45107                        1.04            71.72                    0.718
# 45108                        1.04            71.72                    0.718
# 45109                        1.04            71.72                    0.718
#
#        excess_mortality
# 44592               0.0
# 44593               0.0
# 44594               0.0
# 44595               0.0
# 44596               0.0
# ...                 ...
# 45105               0.0
# 45106               0.0
# 45107               0.0
# 45108               0.0
# 45109               0.0
#
# [518 rows x 60 columns]

# %%
path1=r'C:\Users\Acer\Documents\Belajar Data Science\Source Code Project\Covid19-Report-Indonesia\Dataset\Owid' 
cov19_id_owid = cov19_id_owid.set_index(keys='iso_code')
cov19_id_owid.to_csv(os.path.join(path1, r'cov19_id_owid.csv'))
